# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df=pd.read_csv("annealing_stats_20221217115922.csv") #traffic lights set to red initially
# df=pd.read_csv("annealing_stats_20221218125739.csv") #first speed experiment
# df=pd.read_csv("annealing_stats_20221218164142.csv")#useless (negative speed)

# df=pd.read_csv("annealing_stats_20221218213107.csv")#1 car per frame
# df=pd.read_csv("annealing_stats_20221219014015.csv")#10 cars per frame
# df=pd.read_csv("annealing_stats_20221219014157.csv")#30 cars per frame

# df=pd.read_csv("annealing_stats_20221219014250.csv")#60 cars per frame
df=pd.read_csv(r"optimization_data/genetic_stats_20230102155541.csv")#test
df
# Out:
#      Main index  Population  Unit  Small index  Speed limit(km/h)  \
# 0             1           0     0          0.0                 37
# 1             1           0     0          1.0                 37
# 2             1           0     0          2.0                 37
# 3             1           0     0          NaN                 37
# 4             1           0     1          0.0                 37
# ..          ...         ...   ...          ...                ...
# 795           2           0    98          NaN                 37
# 796           2           0    99          0.0                 37
# 797           2           0    99          1.0                 37
# 798           2           0    99          2.0                 37
# 799           2           0    99          NaN                 37
#
#      Traffic light 0_0  Traffic light 0_1  Traffic light 0_2  \
# 0                 0.96               0.97               0.98
# 1                 0.96               0.97               0.98
# 2                 0.96               0.97               0.98
# 3                 0.96               0.97               0.98
# 4                 0.96               0.97               0.98
# ..                 ...                ...                ...
# 795               0.10               0.11               0.12
# 796               0.42               0.43               0.44
# 797               0.42               0.43               0.44
# 798               0.42               0.43               0.44
# 799               0.42               0.43               0.44
#
#      Traffic light 0_3  Traffic light 1_0  ...  Traffic light 2_2  \
# 0                 0.99               0.96  ...               0.29
# 1                 0.99               0.96  ...               0.29
# 2                 0.99               0.96  ...               0.29
# 3                 0.99               0.96  ...               0.29
# 4                 0.99               0.68  ...               0.98
# ..                 ...                ...  ...                ...
# 795               0.13               0.96  ...               0.98
# 796               0.45               0.96  ...               0.15
# 797               0.45               0.96  ...               0.15
# 798               0.45               0.96  ...               0.15
# 799               0.45               0.96  ...               0.15
#
#      Traffic light 2_3  Traffic light 3_0  Traffic light 3_1  \
# 0                 0.30               0.01               0.02
# 1                 0.30               0.01               0.02
# 2                 0.30               0.01               0.02
# 3                 0.30               0.01               0.02
# 4                 0.99               0.01               0.02
# ..                 ...                ...                ...
# 795               0.99               0.01               0.02
# 796               0.99               0.01               0.02
# 797               0.99               0.01               0.02
# 798               0.99               0.01               0.02
# 799               0.99               0.01               0.02
#
#      Traffic light 3_2  Traffic light 3_3  Flow  Collisions  Stopped  \
# 0                 0.98               0.99   0.0         0.0    False
# 1                 0.98               0.99   0.0         0.0    False
# 2                 0.98               0.99   0.0         0.0    False
# 3                 0.98               0.99   0.0         0.0      NaN
# 4                 0.98               0.99   0.0         0.0    False
# ..                 ...                ...   ...         ...      ...
# 795               0.98               0.99   0.0         0.0      NaN
# 796               0.98               0.99   0.0         0.0    False
# 797               0.98               0.99   0.0         0.0    False
# 798               0.98               0.99   0.0         0.0    False
# 799               0.98               0.99   0.0         0.0      NaN
#
#      Iterations
# 0         100.0
# 1         100.0
# 2         100.0
# 3           NaN
# 4         100.0
# ..          ...
# 795         NaN
# 796       100.0
# 797       100.0
# 798       100.0
# 799         NaN
#
# [800 rows x 25 columns]

# %%
main_results = df[df["Small index"].isna()]
main_results["Cost"]=main_results["Collisions"]*np.log(main_results["Collisions"]+1)-main_results["Flow"]
main_results
# Out:
# C:\Users\yevhe\AppData\Local\Temp\ipykernel_14088\3705816949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_results["Cost"]=main_results["Collisions"]*np.log(main_results["Collisions"]+1)-main_results["Flow"]
#      Main index  Population  Unit  Small index  Speed limit(km/h)  \
# 3             1           0     0          NaN                 37
# 7             1           0     1          NaN                 37
# 11            1           0     2          NaN                 37
# 15            1           0     3          NaN                 37
# 19            1           0     4          NaN                 37
# ..          ...         ...   ...          ...                ...
# 783           2           0    95          NaN                 37
# 787           2           0    96          NaN                 37
# 791           2           0    97          NaN                 37
# 795           2           0    98          NaN                 37
# 799           2           0    99          NaN                 37
#
#      Traffic light 0_0  Traffic light 0_1  Traffic light 0_2  \
# 3                 0.96               0.97               0.98
# 7                 0.96               0.97               0.98
# 11                0.96               0.97               0.98
# 15                0.11               0.12               0.13
# 19                0.96               0.97               0.98
# ..                 ...                ...                ...
# 783               0.96               0.97               0.98
# 787               0.96               0.97               0.98
# 791               0.96               0.97               0.98
# 795               0.10               0.11               0.12
# 799               0.42               0.43               0.44
#
#      Traffic light 0_3  Traffic light 1_0  ...  Traffic light 2_3  \
# 3                 0.99               0.96  ...               0.30
# 7                 0.99               0.68  ...               0.99
# 11                0.99               0.96  ...               0.99
# 15                0.14               0.96  ...               0.99
# 19                0.99               0.96  ...               0.99
# ..                 ...                ...  ...                ...
# 783               0.99               0.96  ...               0.99
# 787               0.77               0.96  ...               0.64
# 791               0.99               0.93  ...               0.99
# 795               0.13               0.96  ...               0.99
# 799               0.45               0.96  ...               0.99
#
#      Traffic light 3_0  Traffic light 3_1  Traffic light 3_2  \
# 3                 0.01               0.02               0.98
# 7                 0.01               0.02               0.98
# 11                0.27               0.02               0.98
# 15                0.01               0.02               0.98
# 19                0.56               0.57               0.53
# ..                 ...                ...                ...
# 783               0.01               0.02               0.74
# 787               0.01               0.02               0.98
# 791               0.01               0.02               0.98
# 795               0.01               0.02               0.98
# 799               0.01               0.02               0.98
#
#      Traffic light 3_3  Flow  Collisions  Stopped  Iterations  Cost
# 3                 0.99   0.0         0.0      NaN         NaN   0.0
# 7                 0.99   0.0         0.0      NaN         NaN   0.0
# 11                0.99   0.0         0.0      NaN         NaN   0.0
# 15                0.99   0.0         0.0      NaN         NaN   0.0
# 19                0.54   0.0         0.0      NaN         NaN   0.0
# ..                 ...   ...         ...      ...         ...   ...
# 783               0.99   0.0         0.0      NaN         NaN   0.0
# 787               0.99   0.0         0.0      NaN         NaN   0.0
# 791               0.99   0.0         0.0      NaN         NaN   0.0
# 795               0.99   0.0         0.0      NaN         NaN   0.0
# 799               0.99   0.0         0.0      NaN         NaN   0.0
#
# [200 rows x 26 columns]

# %%
plt.plot(main_results["Speed limit(km/h)"])

# %%
plt.plot(main_results.Cost)

# %%
plt.plot(main_results.Cost.rolling(30).mean())

# %%
initial_temp=50
cooling_rate=0.99
temp=[initial_temp*cooling_rate**i for i in range(int(main_results.shape[0]-1))]

diff=np.array(main_results.Cost[1:])-np.array(main_results.Cost[:-1])

prob=np.exp(-diff/temp)
prob=[p if p<=1  else 1 for p in prob ]

plt.plot(prob)

# %%
plt.scatter(main_results["Speed limit(km/h)"], main_results["Cost"])

# %% [markdown]
# Only for speed

# %%
regression_data = main_results[~((main_results["Speed limit(km/h)"]>=50) & (main_results["Cost"]>-140))]
regression_data = regression_data[regression_data["Speed limit(km/h)"]>40]
from sklearn.kernel_ridge import KernelRidge
from sklearn.gaussian_process.kernels import DotProduct, Product
score = 0
alphas = [0.05,0.15,0.25,0.5,0.75,1,2,5,10]
X, y = regression_data["Speed limit(km/h)"], regression_data["Cost"]
X=np.array(X).reshape(-1, 1)
for alpha in alphas:
    kernel = Product(DotProduct(),DotProduct())
    krr = KernelRidge(alpha=alpha, kernel=kernel)
    krr.fit(X, y)
    new_score = krr.score(X, y)
    if new_score>score:
        score = new_score
        best_alpha = alpha
kernel = Product(DotProduct(),DotProduct())
krr = KernelRidge(alpha=best_alpha, kernel=kernel)
print(best_alpha)
krr.fit(X, y)
x_new = np.array(range(40,int(np.max(regression_data["Speed limit(km/h)"])))).reshape(-1, 1)
y_new = krr.predict(x_new)
new_score = krr.score(X, y)
if new_score>score:
    score = new_score
    best_alpha = alpha
plt.scatter(regression_data["Speed limit(km/h)"], regression_data["Cost"])
plt.plot(x_new, y_new)
# Out:
# 0.05

# %%
best
# Out:
#      Main index  Population  Unit  Small index  Speed limit(km/h)  \
# 3             1           0     0          NaN                 37
# 7             1           0     1          NaN                 37
# 11            1           0     2          NaN                 37
# 15            1           0     3          NaN                 37
# 19            1           0     4          NaN                 37
# ..          ...         ...   ...          ...                ...
# 783           2           0    95          NaN                 37
# 787           2           0    96          NaN                 37
# 791           2           0    97          NaN                 37
# 795           2           0    98          NaN                 37
# 799           2           0    99          NaN                 37
#
#      Traffic light 0_0  Traffic light 0_1  Traffic light 0_2  \
# 3                 0.96               0.97               0.98
# 7                 0.96               0.97               0.98
# 11                0.96               0.97               0.98
# 15                0.11               0.12               0.13
# 19                0.96               0.97               0.98
# ..                 ...                ...                ...
# 783               0.96               0.97               0.98
# 787               0.96               0.97               0.98
# 791               0.96               0.97               0.98
# 795               0.10               0.11               0.12
# 799               0.42               0.43               0.44
#
#      Traffic light 0_3  Traffic light 1_0  ...  Traffic light 2_3  \
# 3                 0.99               0.96  ...               0.30
# 7                 0.99               0.68  ...               0.99
# 11                0.99               0.96  ...               0.99
# 15                0.14               0.96  ...               0.99
# 19                0.99               0.96  ...               0.99
# ..                 ...                ...  ...                ...
# 783               0.99               0.96  ...               0.99
# 787               0.77               0.96  ...               0.64
# 791               0.99               0.93  ...               0.99
# 795               0.13               0.96  ...               0.99
# 799               0.45               0.96  ...               0.99
#
#      Traffic light 3_0  Traffic light 3_1  Traffic light 3_2  \
# 3                 0.01               0.02               0.98
# 7                 0.01               0.02               0.98
# 11                0.27               0.02               0.98
# 15                0.01               0.02               0.98
# 19                0.56               0.57               0.53
# ..                 ...                ...                ...
# 783               0.01               0.02               0.74
# 787               0.01               0.02               0.98
# 791               0.01               0.02               0.98
# 795               0.01               0.02               0.98
# 799               0.01               0.02               0.98
#
#      Traffic light 3_3  Flow  Collisions  Stopped  Iterations  Cost
# 3                 0.99   0.0         0.0      NaN         NaN   0.0
# 7                 0.99   0.0         0.0      NaN         NaN   0.0
# 11                0.99   0.0         0.0      NaN         NaN   0.0
# 15                0.99   0.0         0.0      NaN         NaN   0.0
# 19                0.54   0.0         0.0      NaN         NaN   0.0
# ..                 ...   ...         ...      ...         ...   ...
# 783               0.99   0.0         0.0      NaN         NaN   0.0
# 787               0.99   0.0         0.0      NaN         NaN   0.0
# 791               0.99   0.0         0.0      NaN         NaN   0.0
# 795               0.99   0.0         0.0      NaN         NaN   0.0
# 799               0.99   0.0         0.0      NaN         NaN   0.0
#
# [189 rows x 26 columns]

# %%
best = main_results[main_results["Cost"]==np.min(main_results.Cost)]
traffic_lights =  best.iloc[:,5:21].values
light_cycles = [traffic_lights[0][4*i:4*i+4] for i in range(4)]
light_cycles
# Out:
# [array([0.96, 0.97, 0.98, 0.99]),
#  array([0.96, 0.97, 0.98, 0.99]),
#  array([0.32, 0.33, 0.29, 0.3 ]),
#  array([0.01, 0.02, 0.98, 0.99])]

# %%
starting_color=["Red","Red","Green","Green"]
plot_data=light_cycles
colors=["Limegreen","Gold","r","Gold"]
plt.figure(figsize=(6,2))
for j in range(4):
    plot_data[j]=np.sort(np.append(plot_data[j],1))
    
    for i in range(5):
        if starting_color[j]=="Red":
            col=colors[i] if i<4 else colors[0] 
        else:
            col=colors[i+2] if i<2 else colors[i-2] 
        
        plt.barh([j],plot_data[j][-i-1],color=col, height=1/2)
plt.axis('off')
plt.show()

# %%
plot_data
# Out:
# [array([0.96, 0.97, 0.98, 0.99, 1.  ]),
#  array([0.96, 0.97, 0.98, 0.99, 1.  ]),
#  array([0.29, 0.3 , 0.32, 0.33, 1.  ]),
#  array([0.01, 0.02, 0.98, 0.99, 1.  ])]

# %%
best5=main_results.sort_values(["Cost"]).head()
best5
# Out:
#      Main index  Population  Unit  Small index  Speed limit(km/h)  \
# 3             1           0     0          NaN                 37
# 507           2           0    26          NaN                 37
# 511           2           0    27          NaN                 37
# 515           2           0    28          NaN                 37
# 519           2           0    29          NaN                 37
#
#      Traffic light 0_0  Traffic light 0_1  Traffic light 0_2  \
# 3                 0.96               0.97               0.98
# 507               0.96               0.97               0.98
# 511               0.96               0.97               0.98
# 515               0.96               0.97               0.98
# 519               0.96               0.97               0.98
#
#      Traffic light 0_3  Traffic light 1_0  ...  Traffic light 2_3  \
# 3                 0.99               0.96  ...               0.30
# 507               0.99               0.84  ...               0.99
# 511               0.99               0.96  ...               0.99
# 515               0.99               0.96  ...               0.99
# 519               0.99               0.96  ...               0.99
#
#      Traffic light 3_0  Traffic light 3_1  Traffic light 3_2  \
# 3                 0.01               0.02               0.98
# 507               0.01               0.02               0.98
# 511               0.01               0.02               0.98
# 515               0.01               0.02               0.98
# 519               0.01               0.02               0.98
#
#      Traffic light 3_3  Flow  Collisions  Stopped  Iterations  Cost
# 3                 0.99   0.0         0.0      NaN         NaN   0.0
# 507               0.99   0.0         0.0      NaN         NaN   0.0
# 511               0.99   0.0         0.0      NaN         NaN   0.0
# 515               0.99   0.0         0.0      NaN         NaN   0.0
# 519               0.99   0.0         0.0      NaN         NaN   0.0
#
# [5 rows x 26 columns]

# %%
for k in range(5):
    value=best5.iloc[k,5:21].values
    light_cycles = [value[4*l:4*l+4] for l in range(4)]
    starting_color=["Red","Red","Green","Green"]
    plot_data=light_cycles
    colors=["Limegreen","Gold","r","Gold"]
    plt.figure(figsize=(6,2))
    for j in range(4):
        plot_data[j]=np.sort(np.append(plot_data[j],1))
        
        for i in range(5):
            if starting_color[j]=="Red":
                col=colors[i] if i<4 else colors[0] 
            else:
                col=colors[i+2] if i<2 else colors[i-2] 
            
            plt.barh([j],plot_data[j][-i-1],color=col, height=1/2)
    plt.axis('off')
    plt.show()
